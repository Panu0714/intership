# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


ds=pd.read_csv("employee_dataset_for_eda.csv")
ds
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 0           1001   50  Female    Marketing         Austin
# 1           1002   36  Female        Sales       New York
# 2           1003   29    Male    Marketing  San Francisco
# 3           1004   42  Female           HR  San Francisco
# 4           1005   40  Female    Marketing         Austin
# ..           ...  ...     ...          ...            ...
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 0                      4          105046               79.6
# 1                      1           59287               71.7
# 2                      5           69711               87.2
# 3                      1           41954               74.4
# 4                     12          103340               82.5
# ..                   ...             ...                ...
# 195                   12           93230               67.3
# 196                    9          104055               58.3
# 197                   17           86373               62.6
# 198                    7           61480               60.7
# 199                    7          115230               75.9
#
# [200 rows x 8 columns]

# %%
ds.duplicated().sum()
# Out:
# np.int64(0)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          200 non-null    int64
#  1   Age                  200 non-null    int64
#  2   Gender               200 non-null    object
#  3   Department           200 non-null    object
#  4   Location             200 non-null    object
#  5   Years_of_Experience  200 non-null    int64
#  6   Monthly_Salary       200 non-null    int64
#  7   Performance_Score    200 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 12.6+ KB

# %%
ds.describe()
# Out:
#        Employee_ID        Age  Years_of_Experience  Monthly_Salary  \
# count   200.000000  200.00000           200.000000      200.000000
# mean   1100.500000   40.17000             9.100000    74330.135000
# std      57.879185   11.24202             5.673707    25761.181642
# min    1001.000000   22.00000             0.000000    30126.000000
# 25%    1050.750000   30.00000             4.000000    50756.750000
# 50%    1100.500000   41.00000             9.000000    74177.500000
# 75%    1150.250000   49.00000            14.000000    97576.500000
# max    1200.000000   59.00000            19.000000   119106.000000
#
#        Performance_Score
# count         200.000000
# mean           71.434000
# std            10.850943
# min            42.200000
# 25%            63.650000
# 50%            71.200000
# 75%            78.225000
# max           101.700000

# %%
#Gender Distribution

sns.countplot(data=ds, x='Gender', palette='coolwarm')
plt.title("Gender Distribution")
# Out:
# C:\Users\buras\AppData\Local\Temp\ipykernel_10960\2309094889.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds, x='Gender', palette='coolwarm')
# Text(0.5, 1.0, 'Gender Distribution')

# %%
sns.countplot(data=ds, x="Department", palette='Set2')

plt.title("Emp count per dept")
plt.show()
# Out:
# C:\Users\buras\AppData\Local\Temp\ipykernel_10960\2681032422.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds, x="Department", palette='Set2')

# %% [markdown]
# Finance dept having more emp count followed by marketing and engineering

# %%
sns.countplot(data=ds, x='Location', palette='Spectral')
plt.title('Number of employees by location')
plt.xticks(rotation=45)
# Out:
# C:\Users\buras\AppData\Local\Temp\ipykernel_10960\1979870698.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds, x='Location', palette='Spectral')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Austin'),
#   Text(1, 0, 'New York'),
#   Text(2, 0, 'San Francisco'),
#   Text(3, 0, 'Seattle'),
#   Text(4, 0, 'Chicago')])

# %% [markdown]
# Number of employee is settle is more followed by new york and san fransico

# %%
sns.histplot(ds['Age'],bins=10, kde=True)
plt.title('Age distribution')
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %%
sns.histplot(ds['Years_of_Experience'],bins=15, kde=True)
plt.title('Years_of_Experience')
# Out:
# Text(0.5, 1.0, 'Years_of_Experience')

# %% [markdown]
# 2.5-5.0 years experience employees are more than other years of experience empolyees

# %%
sns.boxplot(data=ds, y='Monthly_Salary',color='lightblue')
plt.title('Salary Spread')
# Out:
# Text(0.5, 1.0, 'Salary Spread')

# %% [markdown]
# Minimum 20000 salary, maximum is 120000 salary and distributed salary is 75000

# %%
sns.barplot(data=ds, x='Department', y='Monthly_Salary', estimator=np.mean, palette='viridis')
plt.title("Average salary by department")
#plt.show()
# Out:
# C:\Users\buras\AppData\Local\Temp\ipykernel_10960\2617365655.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ds, x='Department', y='Monthly_Salary', estimator=np.mean, palette='viridis')
# Text(0.5, 1.0, 'Average salary by department')

# %%
sns.boxplot(data=ds, x='Department', y='Performance_Score', palette='pastel')
plt.title("Performance score by department")
# Out:
# C:\Users\buras\AppData\Local\Temp\ipykernel_10960\1348924724.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=ds, x='Department', y='Performance_Score', palette='pastel')
# Text(0.5, 1.0, 'Performance score by department')

# %%
sns.violinplot(data=ds, x='Gender', y='Monthly_Salary', palette='muted')
plt.title('Salary by Gender')
# Out:
# C:\Users\buras\AppData\Local\Temp\ipykernel_10960\2750225238.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=ds, x='Gender', y='Monthly_Salary', palette='muted')
# Text(0.5, 1.0, 'Salary by Gender')

# %%
sns.heatmap(ds[['Age','Years_of_Experience','Monthly_Salary','Performance_Score']].corr(),annot=True, cmap='coolwarm')
plt.title('correlational matrix')
# Out:
# Text(0.5, 1.0, 'correlational matrix')

# %%
sns.scatterplot(data=ds, x='Years_of_Experience', y='Monthly_Salary', hue='Department')
plt.title("Salary vs Exp by dept")
# Out:
# Text(0.5, 1.0, 'Salary vs Exp by dept')
